# %%
import pandas as pd
import numpy as np
import os
lc0711 = pd.read_csv('LoanStats3a.csv', engine='python')

# %%
lc0711.loan_amnt.head()
# Out:
# 0     5000.0
# 1     2500.0
# 2     2400.0
# 3    10000.0
# 4     3000.0
# Name: loan_amnt, dtype: float64

# %%
bool_series1 = lc0711.loan_amnt>30000
bool_series1.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: loan_amnt, dtype: bool

# %%
lc0711[bool_series1].head()
# Out:
#       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 31   NaN        NaN    31825.0      31825.0          31825.0   36 months
# 80   NaN        NaN    35000.0      22075.0          22050.0   60 months
# 128  NaN        NaN    35000.0      35000.0          35000.0   36 months
# 185  NaN        NaN    35000.0      35000.0          35000.0   36 months
# 268  NaN        NaN    35000.0      26825.0          26800.0   60 months
#
#     int_rate  installment grade sub_grade       ...        \
# 31     7.90%       995.82     A        A4       ...
# 80    17.27%       551.84     D        D3       ...
# 128    8.90%      1111.37     A        A5       ...
# 185   10.65%      1140.07     B        B2       ...
# 268   18.64%       690.56     E        E1       ...
#
#     hardship_payoff_balance_amount hardship_last_payment_amount  \
# 31                             NaN                          NaN
# 80                             NaN                          NaN
# ...

# %% [markdown]
# ## Showing specific data

# %% [markdown]
# #### 1. Choosing certain columns

# %%
lc0711[bool_series1][['grade', 'sub_grade']].head()
# Out:
#     grade sub_grade
# 31      A        A4
# 80      D        D3
# 128     A        A5
# 185     B        B2
# 268     E        E1

# %% [markdown]
# #### 2. Using boolean series

# %%
bool_series2 = lc0711.notnull().sum()/len(lc0711)>0.9

# %%
column_index = lc0711.columns[bool_series2]

# %%
type(bool_series1)
# Out:
# pandas.core.series.Series

# %%
type(column_index)
# Out:
# pandas.core.indexes.base.Index

# %%
lc0711[bool_series1][column_index].head()
# Out:
#      loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 31     31825.0      31825.0          31825.0   36 months    7.90%
# 80     35000.0      22075.0          22050.0   60 months   17.27%
# 128    35000.0      35000.0          35000.0   36 months    8.90%
# 185    35000.0      35000.0          35000.0   36 months   10.65%
# 268    35000.0      26825.0          26800.0   60 months   18.64%
#
#      installment grade sub_grade                           emp_title  \
# 31        995.82     A        A4  Audubon Mutual Housing Corporation
# 80        551.84     D        D3           tutor Per ini Corporation
# 128      1111.37     A        A5                 City of Los Angeles
# 185      1140.07     B        B2          baylor college of medicine
# 268       690.56     E        E1                      Navistar, Inc.
#
#     emp_length         ...          policy_code  application_type  \
# 31     5 years         ...                    1        Individual
# ...
